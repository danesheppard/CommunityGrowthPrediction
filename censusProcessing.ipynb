# %%
# This is a standalone file to process a Statistics Canada census file for machine learning
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Since we learned what processing needs to be done in the previous file,
# we can now write a function to do this processing

def processCensusData(censusData, year = 2016):
    '''
    This function processes a Statistics Canada census data file for machine learning.
    It handles the different data structures for the 2016 and 2021 census files.
    The function returns a pandas dataframe with the processed data.
    Args:
        censusData: A pandas dataframe containing the census data as imported from the csv file.
        year: The year of the census data. Default is 2016.
    '''
    # If this is 2016 data, let's rename the 'DIM: Profile...' column
    if year == 2016:
        censusData.rename(columns={'DIM: Profile of Census Subdivisions (2247)': 'CHARACTERISTIC_NAME'}, inplace=True)
    # Next we trim the characteristic names
    censusData['CHARACTERISTIC_NAME'] = censusData['CHARACTERISTIC_NAME'].str.replace(r'[^\x00-\x7F]+', '', regex=True)
    censusData['CHARACTERISTIC_NAME'] = censusData['CHARACTERISTIC_NAME'].str.strip()

    # For the 2021 data, we need to split the commnity names on the comma
    # to drop additional subdivision info and match the names with any 2016 data
    if year == 2021:
        censusData['GEO_NAME'] = censusData['GEO_NAME'].str.split(',').str[0]

    # Trim the columns by keywords
    keyWords = ['population', 
                'household', 
                'employment', 
                'industry', 
                'labour', # Labour force information
                'years', # To catch age categories
                'decile', # To catch income decile
                'Employ', # Employment status
                'Unemploy', # Employment status
                'Occupation', # Industry of occupation
                'occupation' # Industry of occupation
                '$', # To catch income values. This will generate a lot of duplicates, but we will handle that later
                ]
    trimmedData = censusData[censusData['CHARACTERISTIC_NAME'].str.contains('|'.join(keyWords), case=False, na=False)]
    # Pivot the table on the 'GEO_NAME' column
    valueColumn = ''
    if year == 2016:
        valueColumn = 'Dim: Sex (3): Member ID: [1]: Total - Sex'
    else: # 2021 data
        valueColumn = 'C1_COUNT_TOTAL'
    pivotedData = trimmedData.pivot_table(index='GEO_NAME', 
                                         columns= 'CHARACTERISTIC_NAME', 
                                         values= valueColumn, 
                                         aggfunc='first')
    # Coerce numeric values
    pivotedData = pivotedData.apply(pd.to_numeric, errors='coerce')
    return pivotedData

# Import the census data from /statCanData
year = 2021
location = 'ON'
fileName = f'{location}_{year}.csv'
encoding = 'ISO-8859-1'
rawData = pd.read_csv(f'statCanData/{fileName}', encoding=encoding)
processedData = processCensusData(rawData, year)

# Save the processed data to a csv file, with a name based on the original file
processedData.to_csv(f'processedData/processed_{fileName}', index=True)
processedData.head()
# Out:
# CHARACTERISTIC_NAME  % of households living in a dwelling provided by the local government, First Nation or Indian band spending more than 30% on shelter costs  \
# GEO_NAME
# Abitibi 70                                                         NaN
# Addington Highlands                                                NaN
# Adelaide-Metcalfe                                                  NaN
# Adjala-Tosorontio                                                  NaN
# Admaston/Bromley                                                   NaN
#
# CHARACTERISTIC_NAME  % of owner households spending 30% or more of its income on shelter costs  \
# GEO_NAME
# Abitibi 70                                                         NaN
# Addington Highlands                                               16.0
# Adelaide-Metcalfe                                                 10.9
# Adjala-Tosorontio                                                 17.0
# Admaston/Bromley                                                   5.0
#
# CHARACTERISTIC_NAME  % of owner households with a mortgage  \
# GEO_NAME
# Abitibi 70                                             NaN
# Addington Highlands                                   47.2
# Adelaide-Metcalfe                                     57.2
# Adjala-Tosorontio                                     61.4
# Admaston/Bromley                                      49.7
#
# CHARACTERISTIC_NAME  % of tenant households in subsidized housing  \
# GEO_NAME
# Abitibi 70                                                    NaN
# Addington Highlands                                          24.4
# Adelaide-Metcalfe                                             0.0
# Adjala-Tosorontio                                             0.0
# Admaston/Bromley                                              0.0
#
# CHARACTERISTIC_NAME  % of tenant households spending 30% or more of its income on shelter costs  \
# GEO_NAME
# Abitibi 70                                                         NaN
# Addington Highlands                                               31.1
# Adelaide-Metcalfe                                                 23.5
# Adjala-Tosorontio                                                 26.4
# Admaston/Bromley                                                  27.3
#
# CHARACTERISTIC_NAME  0 Legislative and senior management occupations  \
# GEO_NAME
# Abitibi 70                                                       0.0
# Addington Highlands                                              0.0
# Adelaide-Metcalfe                                               25.0
# Adjala-Tosorontio                                              115.0
# Admaston/Bromley                                                 0.0
#
# CHARACTERISTIC_NAME  0 to 14 years  0 to 17 years  0 to 17 years (%)  \
# GEO_NAME
# Abitibi 70                    25.0            NaN                NaN
# Addington Highlands          295.0          355.0               14.0
# Adelaide-Metcalfe            600.0          695.0                7.2
# Adjala-Tosorontio           1695.0         2095.0                6.0
# Admaston/Bromley             550.0          670.0               11.2
#
# CHARACTERISTIC_NAME  0 to 4 years  ...  \
# GEO_NAME                           ...
# Abitibi 70                   10.0  ...
# Addington Highlands          90.0  ...
# Adelaide-Metcalfe           175.0  ...
# Adjala-Tosorontio           490.0  ...
# Admaston/Bromley            150.0  ...
#
# CHARACTERISTIC_NAME  Total - Visible minority for the population in private households - 25% sample data  \
# GEO_NAME
# Abitibi 70                                                       150.0
# Addington Highlands                                             2475.0
# Adelaide-Metcalfe                                               2890.0
# Adjala-Tosorontio                                              10955.0
# Admaston/Bromley                                                2995.0
#
# CHARACTERISTIC_NAME  Total number of census families in private households - 100% data  \
# GEO_NAME
# Abitibi 70                                                        45.0
# Addington Highlands                                              765.0
# Adelaide-Metcalfe                                                870.0
# Adjala-Tosorontio                                               3345.0
# Admaston/Bromley                                                 885.0
#
# CHARACTERISTIC_NAME  Total visible minority population  \
# GEO_NAME
# Abitibi 70                                        10.0
# Addington Highlands                                0.0
# Adelaide-Metcalfe                                 40.0
# Adjala-Tosorontio                                740.0
# Admaston/Bromley                                  35.0
#
# CHARACTERISTIC_NAME  Two-maintainer household  \
# GEO_NAME
# Abitibi 70                               20.0
# Addington Highlands                     530.0
# Adelaide-Metcalfe                       570.0
# Adjala-Tosorontio                      2200.0
# Admaston/Bromley                        655.0
#
# CHARACTERISTIC_NAME  Two-or-more-person non-census-family households  \
# GEO_NAME
# Abitibi 70                                                       0.0
# Addington Highlands                                             45.0
# Adelaide-Metcalfe                                               25.0
# Adjala-Tosorontio                                               90.0
# Admaston/Bromley                                                40.0
#
# CHARACTERISTIC_NAME  Under 5 years  Unemployed  Unemployment rate  \
# GEO_NAME
# Abitibi 70                     0.0        15.0               18.8
# Addington Highlands            0.0       140.0               15.3
# Adelaide-Metcalfe             55.0       100.0                5.9
# Adjala-Tosorontio            200.0       560.0                9.0
# Admaston/Bromley              30.0        95.0                5.9
#
# CHARACTERISTIC_NAME  With employment income  Without employment income
# GEO_NAME
# Abitibi 70                              NaN                        NaN
# Addington Highlands                  1170.0                     1015.0
# Adelaide-Metcalfe                    1775.0                      510.0
# Adjala-Tosorontio                    6840.0                     2420.0
# Admaston/Bromley                     1750.0                      690.0
#
# [5 rows x 262 columns]
